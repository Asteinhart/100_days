# %%
import geopandas

myshpfile = geopandas.read_file('CREO_off-campus_assets_Sept2022.shp')
myshpfile.to_file('uchi_geo.geojson', driver='GeoJSON')

# %%
import shapefile

with shapefile.Reader("CREO_off-campus_assets_Sept2022.shp") as shp:
    geojson_data = shp.__geo_interface__

geojson_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'PIN14': '20151040120000',
#     'PIN10': '2015104012',
#     'SHAPE_area': 6727.1248,
#     'SHAPE_len': 369.070618625,
#     'Address': '353 E. Garfield Blvd.',
#     'OwnershipT': 'UChicago owned and managed'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[(1179625.460000001, 1868331.8400000036),
#       (1179621.7800000012, 1868466.3200000003),
#       (1179671.7600000016, 1868467.8999999985),
#       (1179675.4400000013, 1868333.4200000018),
#       (1179625.460000001, 1868331.8400000036)]]}},
#   {'type': 'Feature',
#    'properties': {'PIN14': '20151040130000',
#     'PIN10': '2015104013',
#     'SHAPE_area': 6724.4352,
#     'SHAPE_len': 369.030638605,
#     'Address': '365 E. Garfield Blvd.',
#     'OwnershipT': 'UChicago owned and managed'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[(1179675.4400000013, 1868333.4200000018),
# ...
